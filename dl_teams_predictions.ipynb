# %%
# Import necessary libraries
import tensorflow as tf
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the data
df = pd.read_csv('DL_Secondary_Defense.csv')
metric = 'Current_PFF'  # Metric to predict

# %%
print(df.columns)
# Out:
# Index(['Team', 'Year', 'Position', 'Value_cap_space', 'Value_draft_data',
#        'Current_AV', 'Current_PFF', 'Total DVOA', 'win-loss-pct', 'Net EPA',
#        ...
#        'Previous_snap_counts_pass_rush', 'Previous_snap_counts_run_defense',
#        'Previous_snap_counts_slot', 'Previous_stops', 'Previous_tackles',
#        'Previous_tackles_for_loss', 'Previous_targets',
#        'Previous_total_pressures', 'Previous_touchdowns', 'Previous_yards'],
#       dtype='object', length=108)

# %%
df = df.sort_values(by=['Team', 'Year'])

# Display the sorted data
print(df.head())
# Out:
#       Team  Year Position  Value_cap_space  Value_draft_data  Current_AV  \
# 17   49ers  2019       DL        15.903294       1400.696696        53.0
# 50   49ers  2020       DL         6.755802       1402.398565        39.0
# 70   49ers  2021       DL        18.465753        741.861341        34.0
# 123  49ers  2022       DL        19.298751        752.319057        51.0
# 12   Bears  2019       DL        12.348565         83.494332        29.0
#
#      Current_PFF Total DVOA  win-loss-pct  Net EPA  ...  \
# 17     76.896506     27.90%      0.812500    0.216  ...
# 50     60.632050      5.40%      0.375000    0.025  ...
# 70     70.883348     19.50%      0.588235    0.081  ...
# 123    64.292499     27.60%      0.764706    0.196  ...
# 12     68.035738     -2.10%      0.500000   -0.032  ...
#
#      Previous_snap_counts_pass_rush  Previous_snap_counts_run_defense  \
# 17                       327.077444                        217.831236
# 50                       353.500695                        209.025754
# 70                       294.940888                        187.258985
# 123                      337.180122                        208.407632
# 12                       360.143628                        185.385860
#
#      Previous_snap_counts_slot  Previous_stops  Previous_tackles  \
# 17                    0.268255       20.699975         24.562970
# 50                    0.000000       22.840702         23.495726
# 70                    0.000000       16.922887         19.716530
# 123                   0.000000       24.510602         24.483875
# 12                   11.526329       24.061337         25.095193
#
#      Previous_tackles_for_loss  Previous_targets  Previous_total_pressures  \
# 17                    2.733330          1.496646                 31.275975
# 50                    3.291653          0.811324                 40.765711
# 70                    1.953099          0.764787                 23.851287
# 123                   3.558078          0.730473                 37.372432
# 12                    3.342311          3.383332                 36.086732
#
#      Previous_touchdowns  Previous_yards
# 17              0.000000        9.072853
# 50              0.000000        6.653031
# 70              0.000000        1.390420
# 123             0.000000        1.180706
# 12              0.256608       26.310706
#
# [5 rows x 108 columns]

# %%
team_data = df.groupby('Team')
print(team_data.head)
# Out:
# <bound method GroupBy.head of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x305323b50>>

# %%
import numpy as np

sequences = []
targets = []
teams = []

# Iterate over each team and its respective data
for team, group in team_data:
    teams.append(team)
    # Ensure the team has at least 4 years of data
    if len(group) >= 4:
        print(f"Processing team: {team}, data length: {len(group)}")  # Debugging: check length of data for each team
        
        # Iterate through the data to create sequences for 3 years
        for i in range(len(group) - 3):
            # Select the relevant columns for the sequence
            sequence = group.iloc[i:i+3][['win-loss-pct', 'Value_cap_space', 'weighted_avg_total_pressures', 'weighted_avg_hurries', 'weighted_avg_grades_pass_rush_defense', 
                'Current_AV', 'weighted_avg_sacks', 'weighted_avg_snap_counts_pass_rush']]
  # Add more columns if needed
            
            # The target is the next year's Current_PFF
            target = group.iloc[i+3]['Net EPA']  
            
            sequences.append(sequence.values)  # Add the sequence to the list
            targets.append(target)  # Add the target to the list

# Convert lists to numpy arrays
X = np.array(sequences)
y = np.array(targets)



print(f"Total sequences generated: {len(sequences)}")
print(f"X shape: {X.shape}, y shape: {y.shape}")
# Out:
# Processing team: 49ers, data length: 4
# Processing team: Bears, data length: 4
# Processing team: Bengals, data length: 4
# Processing team: Bills, data length: 4
# Processing team: Broncos, data length: 4
# Processing team: Browns, data length: 4
# Processing team: Buccaneers, data length: 4
# Processing team: Cardinals, data length: 4
# Processing team: Chargers, data length: 4
# Processing team: Chiefs, data length: 4
# Processing team: Colts, data length: 4
# Processing team: Commanders, data length: 4
# Processing team: Cowboys, data length: 4
# Processing team: Dolphins, data length: 4
# Processing team: Eagles, data length: 4
# Processing team: Falcons, data length: 4
# Processing team: Giants, data length: 4
# Processing team: Jaguars, data length: 4
# Processing team: Jets, data length: 4
# Processing team: Lions, data length: 4
# Processing team: Packers, data length: 4
# Processing team: Panthers, data length: 4
# Processing team: Patriots, data length: 4
# Processing team: Raiders, data length: 4
# Processing team: Rams, data length: 4
# Processing team: Ravens, data length: 4
# Processing team: Saints, data length: 4
# Processing team: Seahawks, data length: 4
# Processing team: Steelers, data length: 4
# Processing team: Texans, data length: 4
# Processing team: Titans, data length: 4
# Processing team: Vikings, data length: 4
# Total sequences generated: 32
# X shape: (32, 3, 8), y shape: (32,)

# %%
# Check shape before reshaping
print(X)
print(X.shape)

# Reshape X to (samples, timesteps, features)
X = X.reshape(X.shape[0], 3, -1)  # 3 years per sequence, features will be inferred

print(X.shape)  # Should now be (samples, 3, features)
print(X)
# Out:
# [[[8.12500000e-01 1.59032944e+01 4.17954217e+01 2.83387952e+01
#    7.08843373e+01 5.30000000e+01 6.44722892e+00 3.55822410e+02]
#   [3.75000000e-01 6.75580222e+00 2.44880019e+01 1.72625327e+01
#    6.10913994e+01 3.90000000e+01 3.32881920e+00 2.97716322e+02]
#   [5.88235294e-01 1.84657534e+01 3.71651943e+01 2.46322880e+01
#    7.38876988e+01 3.40000000e+01 6.31515018e+00 3.36845186e+02]]
#
#  [[5.00000000e-01 1.23485654e+01 3.01658302e+01 2.13287327e+01
#    6.45789837e+01 2.90000000e+01 3.68925136e+00 3.25060017e+02]
#   [5.00000000e-01 1.11705348e+01 3.13790340e+01 2.11560852e+01
#    7.13628981e+01 1.80000000e+01 4.36975322e+00 3.16013710e+02]
#   [3.52941176e-01 2.09917808e+01 2.27491266e+01 1.37853712e+01
#    6.68228821e+01 2.20000000e+01 5.94737991e+00 2.39416812e+02]]
#
#  [[1.25000000e-01 1.52231668e+01 3.54996676e+01 2.38967427e+01
#    6.65152670e+01 3.90000000e+01 5.03922003e+00 3.26440727e+02]
#   [2.50000000e-01 4.15741675e+00 2.06452387e+01 1.26749820e+01
#    6.14210842e+01 3.70000000e+01 1.74574238e+00 2.53038858e+02]
#   [5.88235294e-01 1.97972603e+01 3.68205183e+01 2.38727779e+01
#    6.50044978e+01 4.60000000e+01 6.61983294e+00 3.67451274e+02]]
#
#  [[6.25000000e-01 2.43145590e+01 2.88858499e+01 1.88139693e+01
#    6.58539105e+01 5.30000000e+01 4.76763110e+00 3.06665235e+02]
#   [8.12500000e-01 2.58930373e+01 2.78903855e+01 2.10424988e+01
#    6.97806781e+01 4.00000000e+01 2.76010218e+00 2.86078263e+02]
#   [6.47058824e-01 2.32657534e+01 2.65238644e+01 1.88671893e+01
#    6.63947660e+01 4.70000000e+01 3.26954116e+00 2.55881946e+02]]
#
#  [[4.37500000e-01 1.67375133e+01 2.69595549e+01 1.91487267e+01
#    6.27838434e+01 2.90000000e+01 4.31778301e+00 2.58934089e+02]
#   [3.12500000e-01 2.44197780e+00 2.64573858e+01 1.62988310e+01
#    6.82427630e+01 3.00000000e+01 4.82359192e+00 2.83117322e+02]
#   [4.11764706e-01 7.05753425e+00 2.09265052e+01 1.39922863e+01
#    5.89200986e+01 2.70000000e+01 3.16113135e+00 2.66800943e+02]]
#
#  [[3.75000000e-01 6.60998937e+00 2.71538642e+01 1.85727038e+01
#    6.43210947e+01 3.70000000e+01 4.03922950e+00 2.89028659e+02]
#   [6.87500000e-01 1.55196771e+01 3.38985474e+01 2.37761125e+01
#    6.81012912e+01 4.10000000e+01 6.08784874e+00 3.76774729e+02]
#   [4.70588235e-01 8.26301370e+00 3.28501712e+01 2.03921233e+01
#    6.63306721e+01 4.30000000e+01 5.98223459e+00 3.31805651e+02]]
#
#  [[4.37500000e-01 1.67800213e+01 4.29883981e+01 2.75513943e+01
#    6.85568695e+01 2.50000000e+01 6.69794423e+00 4.34109302e+02]
#   [6.87500000e-01 1.69828456e+01 4.02248913e+01 2.78956306e+01
#    6.99944709e+01 2.80000000e+01 5.05280596e+00 4.00328639e+02]
#   [7.64705882e-01 1.63178082e+01 3.50760672e+01 2.36643739e+01
#    6.43906737e+01 3.10000000e+01 4.99028930e+00 3.64840178e+02]]
#
#  [[3.12500000e-01 1.16950053e+01 3.31329588e+01 2.27422753e+01
#    6.81322097e+01 2.10000000e+01 6.58895131e+00 3.55007022e+02]
#   [5.00000000e-01 1.47830474e+00 2.56489099e+01 1.57801316e+01
#    6.65856026e+01 2.80000000e+01 4.38194159e+00 2.57984986e+02]
#   [6.47058824e-01 2.19232877e+01 2.38190699e+01 1.26825228e+01
#    6.95875133e+01 2.90000000e+01 4.41664897e+00 2.76229136e+02]]
#
#  [[3.12500000e-01 5.44102019e+00 3.02721728e+01 2.02025413e+01
#    6.48731131e+01 3.90000000e+01 4.53468869e+00 2.95785006e+02]
#   [4.37500000e-01 5.95358224e+00 2.73761073e+01 1.75161599e+01
#    6.55675126e+01 4.00000000e+01 2.51544170e+00 3.15062006e+02]
#   [5.29411765e-01 1.05534247e+01 2.87218464e+01 1.95216872e+01
#    6.69280939e+01 1.90000000e+01 3.98567449e+00 3.33294668e+02]]
#
#  [[7.50000000e-01 8.07651435e+00 3.13069510e+01 2.07283166e+01
#    6.26115235e+01 4.20000000e+01 5.10969859e+00 3.42904449e+02]
#   [8.75000000e-01 2.25378406e+01 2.81307445e+01 1.80528493e+01
#    6.20718750e+01 4.50000000e+01 3.49701287e+00 3.28407629e+02]
#   [7.05882353e-01 2.54301370e+01 3.33897588e+01 2.27479898e+01
#    6.50734448e+01 3.00000000e+01 4.08273381e+00 3.55571096e+02]]
#
#  [[4.37500000e-01 1.90595112e+01 2.94690418e+01 2.06555283e+01
#    6.30982064e+01 3.20000000e+01 4.18845209e+00 3.26928993e+02]
#   [6.87500000e-01 2.44298688e+01 2.88037109e+01 1.81101074e+01
#    6.63582764e+01 4.20000000e+01 5.57202148e+00 3.47873047e+02]
#   [5.29411765e-01 2.11506849e+01 3.04057471e+01 1.97940230e+01
#    6.61733103e+01 3.70000000e+01 4.78022989e+00 3.48114253e+02]]
#
#  [[1.87500000e-01 6.78533475e+00 3.09647586e+01 2.09344062e+01
#    6.53686494e+01 2.10000000e+01 5.61152984e+00 3.29532084e+02]
#   [4.37500000e-01 1.51967709e+01 3.32901191e+01 2.21772950e+01
#    7.21997431e+01 5.00000000e+01 4.95258117e+00 3.87150432e+02]
#   [4.11764706e-01 1.40383562e+01 3.22671101e+01 2.09382107e+01
#    6.90859472e+01 3.70000000e+01 4.27633555e+00 3.33807767e+02]]
#
#  [[5.00000000e-01 1.59139214e+01 3.62861029e+01 2.46846520e+01
#    6.69350714e+01 4.20000000e+01 4.69508048e+00 3.43570846e+02]
#   [3.75000000e-01 1.16044400e+01 2.32957811e+01 1.64729761e+01
#    6.43680274e+01 3.70000000e+01 2.45267959e+00 2.57121779e+02]
#   [7.05882353e-01 2.08493151e+01 2.58296623e+01 1.81554087e+01
#    6.34415321e+01 4.00000000e+01 3.08002937e+00 2.74830152e+02]]
#
#  [[3.12500000e-01 4.79277365e+00 1.80700293e+01 1.23123170e+01
#    5.88248818e+01 1.70000000e+01 1.96712452e+00 2.48246566e+02]
#   [6.25000000e-01 1.24772957e+01 2.98245211e+01 1.88878672e+01
#    6.61216347e+01 3.30000000e+01 4.49272031e+00 3.24798723e+02]
#   [5.29411765e-01 1.11397260e+01 3.28452232e+01 1.99263663e+01
#    6.63114518e+01 3.20000000e+01 5.30976220e+00 3.41572174e+02]]
#
#  [[5.62500000e-01 1.14080765e+01 4.12188621e+01 2.80935418e+01
#    7.12566889e+01 4.30000000e+01 5.09610456e+00 3.64961814e+02]
#   [2.50000000e-01 1.65338042e+01 3.36020316e+01 2.17562077e+01
#    7.31864560e+01 4.60000000e+01 5.61354402e+00 3.10457111e+02]
#   [5.29411765e-01 1.61534247e+01 3.12139468e+01 2.16973386e+01
#    6.94332164e+01 3.90000000e+01 3.79492470e+00 3.27038374e+02]]
#
#  [[4.37500000e-01 1.92189160e+01 2.84811342e+01 1.96457809e+01
#    6.76440430e+01 4.10000000e+01 4.29796478e+00 3.24537846e+02]
#   [2.50000000e-01 1.58425832e+01 2.73362791e+01 1.91337209e+01
#    6.52237907e+01 4.10000000e+01 2.54883721e+00 3.41166279e+02]
#   [4.11764706e-01 2.32547945e+01 1.43835362e+01 1.03249433e+01
#    5.47802971e+01 1.90000000e+01 9.10047452e-01 2.60561791e+02]]
#
#  [[2.50000000e-01 4.65993624e+00 3.50609832e+01 2.10126530e+01
#    6.24102261e+01 2.40000000e+01 5.03443269e+00 3.78822443e+02]
#   [3.75000000e-01 1.24419778e+01 2.68874172e+01 1.56645353e+01
#    6.68834209e+01 3.30000000e+01 4.51609957e+00 2.84139758e+02]
#   [2.35294118e-01 1.00438356e+01 3.03871099e+01 2.07630726e+01
#    6.30554722e+01 2.80000000e+01 4.84637211e+00 3.48308269e+02]]
#
#  [[3.75000000e-01 1.34856536e+01 3.65388448e+01 2.21266138e+01
#    6.72086070e+01 3.20000000e+01 5.64620612e+00 3.48171914e+02]
#   [6.25000000e-02 3.21897074e+00 1.49108266e+01 8.54979388e+00
#    6.08224127e+01 3.00000000e+01 1.68952050e+00 2.41561510e+02]
#   [1.76470588e-01 9.72054795e+00 2.62399356e+01 1.75776973e+01
#    6.35229871e+01 2.70000000e+01 3.75583736e+00 2.82824879e+02]]
#
#  [[4.37500000e-01 9.90435707e+00 2.04744824e+01 1.33264324e+01
#    6.23789841e+01 3.40000000e+01 3.11242176e+00 2.64017333e+02]
#   [1.25000000e-01 5.99394551e+00 2.42762223e+01 1.65436690e+01
#    6.59054743e+01 2.60000000e+01 3.15775178e+00 2.76740493e+02]
#   [2.35294118e-01 1.13095890e+01 2.33604579e+01 1.53429761e+01
#    6.45700728e+01 3.00000000e+01 2.95254943e+00 2.92186056e+02]]
#
#  [[1.87500000e-01 8.08714134e+00 2.71236559e+01 1.86397849e+01
#    5.94800179e+01 2.70000000e+01 3.35999104e+00 3.08043683e+02]
#   [3.12500000e-01 8.16851665e+00 1.90974984e+01 1.30974984e+01
#    6.48459910e+01 2.10000000e+01 2.91084028e+00 2.51846483e+02]
#   [1.76470588e-01 7.23287671e+00 1.76333957e+01 1.23686837e+01
#    6.30168226e+01 2.00000000e+01 2.96298607e+00 2.55736536e+02]]
#
#  [[8.12500000e-01 1.31668438e+01 4.55181292e+01 3.07680755e+01
#    7.14656082e+01 3.20000000e+01 7.32096117e+00 3.69093542e+02]
#   [8.12500000e-01 2.41220989e+01 2.61652715e+01 1.60985190e+01
#    6.52647993e+01 2.60000000e+01 4.96501395e+00 3.28906418e+02]
#   [7.64705882e-01 2.27342466e+01 4.21072165e+01 3.18224742e+01
#    7.20124948e+01 2.30000000e+01 4.73175258e+00 3.44565155e+02]]
#
#  [[3.12500000e-01 1.54357067e+01 2.79121941e+01 1.69149850e+01
#    6.48019536e+01 1.80000000e+01 5.84328038e+00 2.90144268e+02]
#   [3.12500000e-01 5.07063572e+00 2.64601345e+01 1.62055716e+01
#    6.81033622e+01 3.00000000e+01 3.87704131e+00 2.95692123e+02]
#   [2.94117647e-01 8.49315068e+00 2.87183159e+01 1.71222483e+01
#    6.73660398e+01 3.40000000e+01 5.73968797e+00 3.25587946e+02]]
#
#  [[7.50000000e-01 5.32412327e+00 2.94529607e+01 2.04620919e+01
#    6.61061981e+01 5.20000000e+01 4.69203099e+00 2.91238517e+02]
#   [4.37500000e-01 8.10292634e+00 1.96867215e+01 1.31055229e+01
#    6.29968978e+01 4.90000000e+01 2.51398355e+00 2.28959812e+02]
#   [5.88235294e-01 7.11232877e+00 3.11148459e+01 2.05813598e+01
#    6.46054495e+01 3.30000000e+01 4.69977082e+00 2.99307869e+02]]
#
#  [[4.37500000e-01 7.83740701e+00 2.59177768e+01 1.80796968e+01
#    6.38509646e+01 3.40000000e+01 4.51469913e+00 3.10605420e+02]
#   [5.00000000e-01 1.18314834e+01 2.46345281e+01 1.67733666e+01
#    6.24580762e+01 3.10000000e+01 2.34573503e+00 3.16023367e+02]
#   [5.88235294e-01 1.55452055e+01 4.59727509e+01 3.07694637e+01
#    6.81453287e+01 3.80000000e+01 5.67841696e+00 3.98116133e+02]]
#
#  [[5.62500000e-01 2.33209352e+01 4.24343195e+01 2.90607495e+01
#    6.93660158e+01 3.10000000e+01 7.70138067e+00 3.67156410e+02]
#   [6.25000000e-01 2.16347124e+01 3.71645705e+01 2.44107866e+01
#    6.99898316e+01 5.20000000e+01 7.10488169e+00 3.29755489e+02]
#   [7.05882353e-01 1.74630137e+01 4.39156799e+01 3.12106207e+01
#    7.11329925e+01 4.10000000e+01 7.75080732e+00 3.95507714e+02]]
#
#  [[8.75000000e-01 1.00000000e+01 2.66710051e+01 1.54053989e+01
#    6.24875392e+01 2.20000000e+01 3.39045553e+00 2.83674861e+02]
#   [6.87500000e-01 1.60443996e+01 2.29815963e+01 1.41576315e+01
#    6.31392478e+01 2.80000000e+01 2.91678336e+00 2.75222044e+02]
#   [4.70588235e-01 1.68767123e+01 2.64290288e+01 1.67041622e+01
#    6.48967983e+01 3.00000000e+01 3.37502668e+00 3.08737033e+02]]
#
#  [[8.12500000e-01 9.42082891e+00 3.71786234e+01 2.61698982e+01
#    6.87844886e+01 3.70000000e+01 5.85627727e+00 3.37590887e+02]
#   [7.50000000e-01 1.46064581e+01 3.37659840e+01 2.16283716e+01
#    7.09300200e+01 4.40000000e+01 5.47227772e+00 3.18371628e+02]
#   [5.29411765e-01 1.15780822e+01 2.43585313e+01 1.48468922e+01
#    6.38324934e+01 5.00000000e+01 4.46028318e+00 2.72887689e+02]]
#
#  [[6.87500000e-01 8.20403826e+00 2.25277713e+01 1.60309351e+01
#    5.93359972e+01 2.80000000e+01 2.48277478e+00 3.01224982e+02]
#   [7.50000000e-01 1.19576186e+01 2.65878993e+01 1.60363867e+01
#    6.13814470e+01 2.40000000e+01 4.67082716e+00 3.52000423e+02]
#   [4.11764706e-01 1.02465753e+01 2.45314635e+01 1.58067242e+01
#    6.05352571e+01 3.20000000e+01 3.90938511e+00 3.12857965e+02]]
#
#  [[5.00000000e-01 1.10998937e+01 4.83433606e+01 3.04011603e+01
#    7.89678986e+01 3.30000000e+01 9.18564676e+00 4.00892995e+02]
#   [7.50000000e-01 1.61049445e+01 4.52547391e+01 2.64146965e+01
#    7.55681576e+01 3.50000000e+01 7.19808307e+00 3.55310969e+02]
#   [5.29411765e-01 6.86575342e+00 3.29899558e+01 1.91751708e+01
#    7.14723182e+01 3.50000000e+01 8.24045802e+00 3.50370832e+02]]
#
#  [[6.25000000e-01 1.33634431e+01 2.79403352e+01 1.83579888e+01
#    6.43852067e+01 2.30000000e+01 3.72022346e+00 3.21736760e+02]
#   [2.50000000e-01 9.92936428e+00 2.05449076e+01 1.21996132e+01
#    6.18833477e+01 2.20000000e+01 2.89600344e+00 2.97929308e+02]
#   [2.35294118e-01 5.86849315e+00 2.25942721e+01 1.61670644e+01
#    6.60970167e+01 3.20000000e+01 2.75990453e+00 2.55838425e+02]]
#
#  [[5.62500000e-01 1.36131775e+01 2.54664271e+01 1.86409162e+01
#    6.25637323e+01 2.80000000e+01 3.77790254e+00 3.18259600e+02]
#   [6.87500000e-01 6.86680121e+00 2.92858770e+01 1.98615034e+01
#    6.20767882e+01 2.20000000e+01 2.53052392e+00 3.69711390e+02]
#   [7.05882353e-01 5.17260274e+00 3.95312703e+01 2.61542956e+01
#    6.28744860e+01 3.30000000e+01 7.63730794e+00 3.91062973e+02]]
#
#  [[6.25000000e-01 1.97980871e+01 3.96777599e+01 2.62242369e+01
#    6.75313978e+01 4.30000000e+01 6.71631857e+00 3.81117742e+02]
#   [4.37500000e-01 5.08072654e+00 1.82241249e+01 1.24908084e+01
#    5.72730546e+01 3.10000000e+01 1.86300680e+00 3.12098716e+02]
#   [4.70588235e-01 8.87123288e+00 2.87414082e+01 1.90343671e+01
#    6.66891660e+01 3.20000000e+01 4.73323554e+00 3.64446773e+02]]]
# (32, 3, 8)
# (32, 3, 8)
# [[[8.12500000e-01 1.59032944e+01 4.17954217e+01 2.83387952e+01
#    7.08843373e+01 5.30000000e+01 6.44722892e+00 3.55822410e+02]
#   [3.75000000e-01 6.75580222e+00 2.44880019e+01 1.72625327e+01
#    6.10913994e+01 3.90000000e+01 3.32881920e+00 2.97716322e+02]
#   [5.88235294e-01 1.84657534e+01 3.71651943e+01 2.46322880e+01
#    7.38876988e+01 3.40000000e+01 6.31515018e+00 3.36845186e+02]]
#
#  [[5.00000000e-01 1.23485654e+01 3.01658302e+01 2.13287327e+01
#    6.45789837e+01 2.90000000e+01 3.68925136e+00 3.25060017e+02]
#   [5.00000000e-01 1.11705348e+01 3.13790340e+01 2.11560852e+01
#    7.13628981e+01 1.80000000e+01 4.36975322e+00 3.16013710e+02]
#   [3.52941176e-01 2.09917808e+01 2.27491266e+01 1.37853712e+01
#    6.68228821e+01 2.20000000e+01 5.94737991e+00 2.39416812e+02]]
#
#  [[1.25000000e-01 1.52231668e+01 3.54996676e+01 2.38967427e+01
#    6.65152670e+01 3.90000000e+01 5.03922003e+00 3.26440727e+02]
#   [2.50000000e-01 4.15741675e+00 2.06452387e+01 1.26749820e+01
#    6.14210842e+01 3.70000000e+01 1.74574238e+00 2.53038858e+02]
#   [5.88235294e-01 1.97972603e+01 3.68205183e+01 2.38727779e+01
#    6.50044978e+01 4.60000000e+01 6.61983294e+00 3.67451274e+02]]
#
#  [[6.25000000e-01 2.43145590e+01 2.88858499e+01 1.88139693e+01
#    6.58539105e+01 5.30000000e+01 4.76763110e+00 3.06665235e+02]
#   [8.12500000e-01 2.58930373e+01 2.78903855e+01 2.10424988e+01
#    6.97806781e+01 4.00000000e+01 2.76010218e+00 2.86078263e+02]
#   [6.47058824e-01 2.32657534e+01 2.65238644e+01 1.88671893e+01
#    6.63947660e+01 4.70000000e+01 3.26954116e+00 2.55881946e+02]]
#
#  [[4.37500000e-01 1.67375133e+01 2.69595549e+01 1.91487267e+01
#    6.27838434e+01 2.90000000e+01 4.31778301e+00 2.58934089e+02]
#   [3.12500000e-01 2.44197780e+00 2.64573858e+01 1.62988310e+01
#    6.82427630e+01 3.00000000e+01 4.82359192e+00 2.83117322e+02]
#   [4.11764706e-01 7.05753425e+00 2.09265052e+01 1.39922863e+01
#    5.89200986e+01 2.70000000e+01 3.16113135e+00 2.66800943e+02]]
#
#  [[3.75000000e-01 6.60998937e+00 2.71538642e+01 1.85727038e+01
#    6.43210947e+01 3.70000000e+01 4.03922950e+00 2.89028659e+02]
#   [6.87500000e-01 1.55196771e+01 3.38985474e+01 2.37761125e+01
#    6.81012912e+01 4.10000000e+01 6.08784874e+00 3.76774729e+02]
#   [4.70588235e-01 8.26301370e+00 3.28501712e+01 2.03921233e+01
#    6.63306721e+01 4.30000000e+01 5.98223459e+00 3.31805651e+02]]
#
#  [[4.37500000e-01 1.67800213e+01 4.29883981e+01 2.75513943e+01
#    6.85568695e+01 2.50000000e+01 6.69794423e+00 4.34109302e+02]
#   [6.87500000e-01 1.69828456e+01 4.02248913e+01 2.78956306e+01
#    6.99944709e+01 2.80000000e+01 5.05280596e+00 4.00328639e+02]
#   [7.64705882e-01 1.63178082e+01 3.50760672e+01 2.36643739e+01
#    6.43906737e+01 3.10000000e+01 4.99028930e+00 3.64840178e+02]]
#
#  [[3.12500000e-01 1.16950053e+01 3.31329588e+01 2.27422753e+01
#    6.81322097e+01 2.10000000e+01 6.58895131e+00 3.55007022e+02]
#   [5.00000000e-01 1.47830474e+00 2.56489099e+01 1.57801316e+01
#    6.65856026e+01 2.80000000e+01 4.38194159e+00 2.57984986e+02]
#   [6.47058824e-01 2.19232877e+01 2.38190699e+01 1.26825228e+01
#    6.95875133e+01 2.90000000e+01 4.41664897e+00 2.76229136e+02]]
#
#  [[3.12500000e-01 5.44102019e+00 3.02721728e+01 2.02025413e+01
#    6.48731131e+01 3.90000000e+01 4.53468869e+00 2.95785006e+02]
#   [4.37500000e-01 5.95358224e+00 2.73761073e+01 1.75161599e+01
#    6.55675126e+01 4.00000000e+01 2.51544170e+00 3.15062006e+02]
#   [5.29411765e-01 1.05534247e+01 2.87218464e+01 1.95216872e+01
#    6.69280939e+01 1.90000000e+01 3.98567449e+00 3.33294668e+02]]
#
#  [[7.50000000e-01 8.07651435e+00 3.13069510e+01 2.07283166e+01
#    6.26115235e+01 4.20000000e+01 5.10969859e+00 3.42904449e+02]
#   [8.75000000e-01 2.25378406e+01 2.81307445e+01 1.80528493e+01
#    6.20718750e+01 4.50000000e+01 3.49701287e+00 3.28407629e+02]
#   [7.05882353e-01 2.54301370e+01 3.33897588e+01 2.27479898e+01
#    6.50734448e+01 3.00000000e+01 4.08273381e+00 3.55571096e+02]]
#
#  [[4.37500000e-01 1.90595112e+01 2.94690418e+01 2.06555283e+01
#    6.30982064e+01 3.20000000e+01 4.18845209e+00 3.26928993e+02]
#   [6.87500000e-01 2.44298688e+01 2.88037109e+01 1.81101074e+01
#    6.63582764e+01 4.20000000e+01 5.57202148e+00 3.47873047e+02]
#   [5.29411765e-01 2.11506849e+01 3.04057471e+01 1.97940230e+01
#    6.61733103e+01 3.70000000e+01 4.78022989e+00 3.48114253e+02]]
#
#  [[1.87500000e-01 6.78533475e+00 3.09647586e+01 2.09344062e+01
#    6.53686494e+01 2.10000000e+01 5.61152984e+00 3.29532084e+02]
#   [4.37500000e-01 1.51967709e+01 3.32901191e+01 2.21772950e+01
#    7.21997431e+01 5.00000000e+01 4.95258117e+00 3.87150432e+02]
#   [4.11764706e-01 1.40383562e+01 3.22671101e+01 2.09382107e+01
#    6.90859472e+01 3.70000000e+01 4.27633555e+00 3.33807767e+02]]
#
#  [[5.00000000e-01 1.59139214e+01 3.62861029e+01 2.46846520e+01
#    6.69350714e+01 4.20000000e+01 4.69508048e+00 3.43570846e+02]
#   [3.75000000e-01 1.16044400e+01 2.32957811e+01 1.64729761e+01
#    6.43680274e+01 3.70000000e+01 2.45267959e+00 2.57121779e+02]
#   [7.05882353e-01 2.08493151e+01 2.58296623e+01 1.81554087e+01
#    6.34415321e+01 4.00000000e+01 3.08002937e+00 2.74830152e+02]]
#
#  [[3.12500000e-01 4.79277365e+00 1.80700293e+01 1.23123170e+01
#    5.88248818e+01 1.70000000e+01 1.96712452e+00 2.48246566e+02]
#   [6.25000000e-01 1.24772957e+01 2.98245211e+01 1.88878672e+01
#    6.61216347e+01 3.30000000e+01 4.49272031e+00 3.24798723e+02]
#   [5.29411765e-01 1.11397260e+01 3.28452232e+01 1.99263663e+01
#    6.63114518e+01 3.20000000e+01 5.30976220e+00 3.41572174e+02]]
#
#  [[5.62500000e-01 1.14080765e+01 4.12188621e+01 2.80935418e+01
#    7.12566889e+01 4.30000000e+01 5.09610456e+00 3.64961814e+02]
#   [2.50000000e-01 1.65338042e+01 3.36020316e+01 2.17562077e+01
#    7.31864560e+01 4.60000000e+01 5.61354402e+00 3.10457111e+02]
#   [5.29411765e-01 1.61534247e+01 3.12139468e+01 2.16973386e+01
#    6.94332164e+01 3.90000000e+01 3.79492470e+00 3.27038374e+02]]
#
#  [[4.37500000e-01 1.92189160e+01 2.84811342e+01 1.96457809e+01
#    6.76440430e+01 4.10000000e+01 4.29796478e+00 3.24537846e+02]
#   [2.50000000e-01 1.58425832e+01 2.73362791e+01 1.91337209e+01
#    6.52237907e+01 4.10000000e+01 2.54883721e+00 3.41166279e+02]
#   [4.11764706e-01 2.32547945e+01 1.43835362e+01 1.03249433e+01
#    5.47802971e+01 1.90000000e+01 9.10047452e-01 2.60561791e+02]]
#
#  [[2.50000000e-01 4.65993624e+00 3.50609832e+01 2.10126530e+01
#    6.24102261e+01 2.40000000e+01 5.03443269e+00 3.78822443e+02]
#   [3.75000000e-01 1.24419778e+01 2.68874172e+01 1.56645353e+01
#    6.68834209e+01 3.30000000e+01 4.51609957e+00 2.84139758e+02]
#   [2.35294118e-01 1.00438356e+01 3.03871099e+01 2.07630726e+01
#    6.30554722e+01 2.80000000e+01 4.84637211e+00 3.48308269e+02]]
#
#  [[3.75000000e-01 1.34856536e+01 3.65388448e+01 2.21266138e+01
#    6.72086070e+01 3.20000000e+01 5.64620612e+00 3.48171914e+02]
#   [6.25000000e-02 3.21897074e+00 1.49108266e+01 8.54979388e+00
#    6.08224127e+01 3.00000000e+01 1.68952050e+00 2.41561510e+02]
#   [1.76470588e-01 9.72054795e+00 2.62399356e+01 1.75776973e+01
#    6.35229871e+01 2.70000000e+01 3.75583736e+00 2.82824879e+02]]
#
#  [[4.37500000e-01 9.90435707e+00 2.04744824e+01 1.33264324e+01
#    6.23789841e+01 3.40000000e+01 3.11242176e+00 2.64017333e+02]
#   [1.25000000e-01 5.99394551e+00 2.42762223e+01 1.65436690e+01
#    6.59054743e+01 2.60000000e+01 3.15775178e+00 2.76740493e+02]
#   [2.35294118e-01 1.13095890e+01 2.33604579e+01 1.53429761e+01
#    6.45700728e+01 3.00000000e+01 2.95254943e+00 2.92186056e+02]]
#
#  [[1.87500000e-01 8.08714134e+00 2.71236559e+01 1.86397849e+01
#    5.94800179e+01 2.70000000e+01 3.35999104e+00 3.08043683e+02]
#   [3.12500000e-01 8.16851665e+00 1.90974984e+01 1.30974984e+01
#    6.48459910e+01 2.10000000e+01 2.91084028e+00 2.51846483e+02]
#   [1.76470588e-01 7.23287671e+00 1.76333957e+01 1.23686837e+01
#    6.30168226e+01 2.00000000e+01 2.96298607e+00 2.55736536e+02]]
#
#  [[8.12500000e-01 1.31668438e+01 4.55181292e+01 3.07680755e+01
#    7.14656082e+01 3.20000000e+01 7.32096117e+00 3.69093542e+02]
#   [8.12500000e-01 2.41220989e+01 2.61652715e+01 1.60985190e+01
#    6.52647993e+01 2.60000000e+01 4.96501395e+00 3.28906418e+02]
#   [7.64705882e-01 2.27342466e+01 4.21072165e+01 3.18224742e+01
#    7.20124948e+01 2.30000000e+01 4.73175258e+00 3.44565155e+02]]
#
#  [[3.12500000e-01 1.54357067e+01 2.79121941e+01 1.69149850e+01
#    6.48019536e+01 1.80000000e+01 5.84328038e+00 2.90144268e+02]
#   [3.12500000e-01 5.07063572e+00 2.64601345e+01 1.62055716e+01
#    6.81033622e+01 3.00000000e+01 3.87704131e+00 2.95692123e+02]
#   [2.94117647e-01 8.49315068e+00 2.87183159e+01 1.71222483e+01
#    6.73660398e+01 3.40000000e+01 5.73968797e+00 3.25587946e+02]]
#
#  [[7.50000000e-01 5.32412327e+00 2.94529607e+01 2.04620919e+01
#    6.61061981e+01 5.20000000e+01 4.69203099e+00 2.91238517e+02]
#   [4.37500000e-01 8.10292634e+00 1.96867215e+01 1.31055229e+01
#    6.29968978e+01 4.90000000e+01 2.51398355e+00 2.28959812e+02]
#   [5.88235294e-01 7.11232877e+00 3.11148459e+01 2.05813598e+01
#    6.46054495e+01 3.30000000e+01 4.69977082e+00 2.99307869e+02]]
#
#  [[4.37500000e-01 7.83740701e+00 2.59177768e+01 1.80796968e+01
#    6.38509646e+01 3.40000000e+01 4.51469913e+00 3.10605420e+02]
#   [5.00000000e-01 1.18314834e+01 2.46345281e+01 1.67733666e+01
#    6.24580762e+01 3.10000000e+01 2.34573503e+00 3.16023367e+02]
#   [5.88235294e-01 1.55452055e+01 4.59727509e+01 3.07694637e+01
#    6.81453287e+01 3.80000000e+01 5.67841696e+00 3.98116133e+02]]
#
#  [[5.62500000e-01 2.33209352e+01 4.24343195e+01 2.90607495e+01
#    6.93660158e+01 3.10000000e+01 7.70138067e+00 3.67156410e+02]
#   [6.25000000e-01 2.16347124e+01 3.71645705e+01 2.44107866e+01
#    6.99898316e+01 5.20000000e+01 7.10488169e+00 3.29755489e+02]
#   [7.05882353e-01 1.74630137e+01 4.39156799e+01 3.12106207e+01
#    7.11329925e+01 4.10000000e+01 7.75080732e+00 3.95507714e+02]]
#
#  [[8.75000000e-01 1.00000000e+01 2.66710051e+01 1.54053989e+01
#    6.24875392e+01 2.20000000e+01 3.39045553e+00 2.83674861e+02]
#   [6.87500000e-01 1.60443996e+01 2.29815963e+01 1.41576315e+01
#    6.31392478e+01 2.80000000e+01 2.91678336e+00 2.75222044e+02]
#   [4.70588235e-01 1.68767123e+01 2.64290288e+01 1.67041622e+01
#    6.48967983e+01 3.00000000e+01 3.37502668e+00 3.08737033e+02]]
#
#  [[8.12500000e-01 9.42082891e+00 3.71786234e+01 2.61698982e+01
#    6.87844886e+01 3.70000000e+01 5.85627727e+00 3.37590887e+02]
#   [7.50000000e-01 1.46064581e+01 3.37659840e+01 2.16283716e+01
#    7.09300200e+01 4.40000000e+01 5.47227772e+00 3.18371628e+02]
#   [5.29411765e-01 1.15780822e+01 2.43585313e+01 1.48468922e+01
#    6.38324934e+01 5.00000000e+01 4.46028318e+00 2.72887689e+02]]
#
#  [[6.87500000e-01 8.20403826e+00 2.25277713e+01 1.60309351e+01
#    5.93359972e+01 2.80000000e+01 2.48277478e+00 3.01224982e+02]
#   [7.50000000e-01 1.19576186e+01 2.65878993e+01 1.60363867e+01
#    6.13814470e+01 2.40000000e+01 4.67082716e+00 3.52000423e+02]
#   [4.11764706e-01 1.02465753e+01 2.45314635e+01 1.58067242e+01
#    6.05352571e+01 3.20000000e+01 3.90938511e+00 3.12857965e+02]]
#
#  [[5.00000000e-01 1.10998937e+01 4.83433606e+01 3.04011603e+01
#    7.89678986e+01 3.30000000e+01 9.18564676e+00 4.00892995e+02]
#   [7.50000000e-01 1.61049445e+01 4.52547391e+01 2.64146965e+01
#    7.55681576e+01 3.50000000e+01 7.19808307e+00 3.55310969e+02]
#   [5.29411765e-01 6.86575342e+00 3.29899558e+01 1.91751708e+01
#    7.14723182e+01 3.50000000e+01 8.24045802e+00 3.50370832e+02]]
#
#  [[6.25000000e-01 1.33634431e+01 2.79403352e+01 1.83579888e+01
#    6.43852067e+01 2.30000000e+01 3.72022346e+00 3.21736760e+02]
#   [2.50000000e-01 9.92936428e+00 2.05449076e+01 1.21996132e+01
#    6.18833477e+01 2.20000000e+01 2.89600344e+00 2.97929308e+02]
#   [2.35294118e-01 5.86849315e+00 2.25942721e+01 1.61670644e+01
#    6.60970167e+01 3.20000000e+01 2.75990453e+00 2.55838425e+02]]
#
#  [[5.62500000e-01 1.36131775e+01 2.54664271e+01 1.86409162e+01
#    6.25637323e+01 2.80000000e+01 3.77790254e+00 3.18259600e+02]
#   [6.87500000e-01 6.86680121e+00 2.92858770e+01 1.98615034e+01
#    6.20767882e+01 2.20000000e+01 2.53052392e+00 3.69711390e+02]
#   [7.05882353e-01 5.17260274e+00 3.95312703e+01 2.61542956e+01
#    6.28744860e+01 3.30000000e+01 7.63730794e+00 3.91062973e+02]]
#
#  [[6.25000000e-01 1.97980871e+01 3.96777599e+01 2.62242369e+01
#    6.75313978e+01 4.30000000e+01 6.71631857e+00 3.81117742e+02]
#   [4.37500000e-01 5.08072654e+00 1.82241249e+01 1.24908084e+01
#    5.72730546e+01 3.10000000e+01 1.86300680e+00 3.12098716e+02]
#   [4.70588235e-01 8.87123288e+00 2.87414082e+01 1.90343671e+01
#    6.66891660e+01 3.20000000e+01 4.73323554e+00 3.64446773e+02]]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, SimpleRNN, MultiHeadAttention, LayerNormalization, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Define the input layer
inputs = Input(shape=(3, 8))  # 3 time steps, 8 features

# Add a Dense layer before the attention to create more variability in the input
dense_input = Dense(16, activation='relu')(inputs)

# Add MultiHeadAttention layer
attention_output = MultiHeadAttention(num_heads=2, key_dim=8)(dense_input, dense_input)

# Add Layer Normalization for stability
attention_output = LayerNormalization()(attention_output)

# Add RNN layer to capture temporal dependencies
rnn_output = SimpleRNN(units=50, activation='relu')(attention_output)

# Add Dropout to prevent overfitting
rnn_output = Dropout(0.2)(rnn_output)

# Output layer for predicting Current PFF
output = Dense(1)(rnn_output)

# Define the model
model = Model(inputs=inputs, outputs=output)

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Early stopping callback to monitor validation loss
#early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# %%
# Train the model
#history = model.fit(X, y, epochs=100, batch_size=8, validation_split=0.2, callbacks=[early_stopping])
epoch_list = [50, 100, 150, 200]
for e in epoch_list:
    history = model.fit(X, y, epochs=e, batch_size=8, validation_split=0.2, callbacks=[early_stopping])
    # Plot training & validation loss
    plt.figure(figsize=(10, 5))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.title('Training vs Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    # Make predictions on the test set
    y_pred = model.predict(X)
    print(len(y_pred))
    from sklearn.metrics import r2_score

    # Calculate R² score
    r2 = r2_score(y, y_pred)

    # Print R² score
    print(f"R² Score: {r2:.4f}")
    data = df[df['Year'] == 2022].copy()
    data['Predicted_Net_EPA'] = y_pred
    data['Model Actual Net EPA'] = y
    divisions = {
    "49ers": "NFC West", "Bears": "NFC North", "Bengals": "AFC North", "Bills": "AFC East",
    "Broncos": "AFC West", "Browns": "AFC North", "Buccaneers": "NFC South",
    "Cardinals": "NFC West", "Chargers": "AFC West", "Chiefs": "AFC West", "Colts": "AFC South",
    "Commanders": "NFC East", "Cowboys": "NFC East", "Dolphins": "AFC East", "Eagles": "NFC East",
    "Falcons": "NFC South", "Giants": "NFC East", "Jaguars": "AFC South", "Jets": "AFC East",
    "Lions": "NFC North", "Packers": "NFC North", "Panthers": "NFC South", "Patriots": "AFC East",
    "Raiders": "AFC West", "Rams": "NFC West", "Ravens": "AFC North", "Saints": "NFC South",
    "Seahawks": "NFC West", "Steelers": "AFC North", "Texans": "AFC South", "Titans": "AFC South",
    "Vikings": "NFC North"
}

    # Add the "Division" column
    data["Division"] = data["Team"].map(divisions)
    columns_to_keep = ['Net EPA', 'Predicted_Net_EPA', 'Team', 'Model Actual Net EPA', 'Division']
    data = data.loc[:, columns_to_keep]
    
    divisions = data["Division"].unique()
    fig, axes = plt.subplots(4, 2, figsize=(20, 20))  # 4 rows, 2 columns

    for ax, division in zip(axes.flatten(), divisions):
        fig.suptitle('Actual vs Predicted Net EPA by Division using QB Data for 2022', fontsize=16)
        division_data = data[data["Division"] == division]
        x = np.arange(4)  # Generate x-axis positions
        width = 0.4  # Bar width
        # Plot actual and predicted for this division
        ax.bar(x - width / 2, division_data['Net EPA'], width, label='Actual', color='#19D373')  # Hex for Actual
        ax.bar(x + width / 2, division_data['Predicted_Net_EPA'], width, label='Predicted', color='#7606FC')  # Hex for Predicted
        
        ax.set_xticks(x)
        ax.set_xticklabels(division_data['Team'], rotation=45, ha='right')
        ax.set_title(division)
        ax.set_xlabel('Teams')
        ax.set_ylabel('Net EPA')
        ax.legend()

    plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout to fit the title
    plt.show()
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.4851 - val_loss: 0.1541
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2392 - val_loss: 0.0095
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3051 - val_loss: 0.0125
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2651 - val_loss: 0.0136
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1711 - val_loss: 0.0174
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1099 - val_loss: 0.0894
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2039 - val_loss: 0.0072
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0798 - val_loss: 0.0282
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1389 - val_loss: 0.0145
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0695 - val_loss: 0.0043
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0612 - val_loss: 0.0078
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1202 - val_loss: 0.0084
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1274 - val_loss: 0.0370
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1290 - val_loss: 0.0234
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0723 - val_loss: 0.0069
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0785 - val_loss: 0.0143
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0528 - val_loss: 0.0046
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0732 - val_loss: 0.0184
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0570 - val_loss: 0.0073
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0441 - val_loss: 0.0048
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0234 - val_loss: 0.0081
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0452 - val_loss: 0.0036
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0154 - val_loss: 0.0040
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0351 - val_loss: 0.0044
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0305 - val_loss: 0.0048
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0187 - val_loss: 0.0140
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0352 - val_loss: 0.0190
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0532 - val_loss: 0.0038
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0135 - val_loss: 0.0082
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0209 - val_loss: 0.0041
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0134 - val_loss: 0.0060
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0289 - val_loss: 0.0074
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0187 - val_loss: 0.0060
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0393 - val_loss: 0.0077
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0355 - val_loss: 0.0068
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0183 - val_loss: 0.0047
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0300 - val_loss: 0.0062
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0136 - val_loss: 0.0098
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0172 - val_loss: 0.0106
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0176 - val_loss: 0.0077
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0169 - val_loss: 0.0106
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0154 - val_loss: 0.0118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 32
# R² Score: -0.1019
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0619 - val_loss: 0.0073
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0332 - val_loss: 0.0090
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0197 - val_loss: 0.0053
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0221 - val_loss: 0.0046
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0226 - val_loss: 0.0102
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0321 - val_loss: 0.0199
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0582 - val_loss: 0.0045
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0233 - val_loss: 0.0085
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0249 - val_loss: 0.0072
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0363 - val_loss: 0.0126
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0310 - val_loss: 0.0143
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0286 - val_loss: 0.0041
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0348 - val_loss: 0.0047
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0265 - val_loss: 0.0041
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0257 - val_loss: 0.0050
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0243 - val_loss: 0.0051
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0144 - val_loss: 0.0067
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0188 - val_loss: 0.0091
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0163 - val_loss: 0.0069
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - val_loss: 0.0046
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 32
# R² Score: -0.0514
# Epoch 1/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0400 - val_loss: 0.0045
# Epoch 2/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0339 - val_loss: 0.0056
# Epoch 3/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0303 - val_loss: 0.0122
# Epoch 4/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0255 - val_loss: 0.0173
# Epoch 5/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209 - val_loss: 0.0095
# Epoch 6/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0279 - val_loss: 0.0041
# Epoch 7/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0193 - val_loss: 0.0038
# Epoch 8/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0177 - val_loss: 0.0039
# Epoch 9/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0365 - val_loss: 0.0123
# Epoch 10/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0436 - val_loss: 0.0121
# Epoch 11/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0253 - val_loss: 0.0036
# Epoch 12/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0283 - val_loss: 0.0036
# Epoch 13/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0244 - val_loss: 0.0088
# Epoch 14/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0272 - val_loss: 0.0133
# Epoch 15/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0216 - val_loss: 0.0041
# Epoch 16/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0145 - val_loss: 0.0039
# Epoch 17/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - val_loss: 0.0092
# Epoch 18/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184 - val_loss: 0.0096
# Epoch 19/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0201 - val_loss: 0.0034
# Epoch 20/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0122 - val_loss: 0.0063
# Epoch 21/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0144 - val_loss: 0.0058
# Epoch 22/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0155 - val_loss: 0.0075
# Epoch 23/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0114 - val_loss: 0.0075
# Epoch 24/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0129 - val_loss: 0.0051
# Epoch 25/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0154 - val_loss: 0.0049
# Epoch 26/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0247 - val_loss: 0.0100
# Epoch 27/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0118 - val_loss: 0.0075
# Epoch 28/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0075 - val_loss: 0.0084
# Epoch 29/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0142 - val_loss: 0.0111
# Epoch 30/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0226 - val_loss: 0.0074
# Epoch 31/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0128 - val_loss: 0.0042
# Epoch 32/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0085 - val_loss: 0.0047
# Epoch 33/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0205 - val_loss: 0.0057
# Epoch 34/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164 - val_loss: 0.0091
# Epoch 35/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0129 - val_loss: 0.0121
# Epoch 36/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0135 - val_loss: 0.0074
# Epoch 37/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0147 - val_loss: 0.0048
# Epoch 38/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0114 - val_loss: 0.0042
# Epoch 39/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0131 - val_loss: 0.0046
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 32
# R² Score: -0.0097
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0213 - val_loss: 0.0060
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0074 - val_loss: 0.0101
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0154 - val_loss: 0.0089
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0111 - val_loss: 0.0039
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0144 - val_loss: 0.0033
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0111 - val_loss: 0.0048
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0116 - val_loss: 0.0068
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0130 - val_loss: 0.0046
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0125 - val_loss: 0.0053
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - val_loss: 0.0049
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0118 - val_loss: 0.0034
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0129 - val_loss: 0.0040
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0114 - val_loss: 0.0075
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0162 - val_loss: 0.0086
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0131 - val_loss: 0.0096
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0150 - val_loss: 0.0112
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0103 - val_loss: 0.0069
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0150 - val_loss: 0.0036
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0168 - val_loss: 0.0036
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0163 - val_loss: 0.0057
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0143 - val_loss: 0.0096
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0062 - val_loss: 0.0128
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0133 - val_loss: 0.0096
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0071 - val_loss: 0.0079
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0137 - val_loss: 0.0042
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 32
# R² Score: 0.0350
